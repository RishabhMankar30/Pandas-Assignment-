# %%
import pandas as pd

# %%
#1 . load this data in pandas.

df_order=pd.read_excel(r"C:\Users\Dell\Documents\Ineuron FSDS Resourse\(20) Pandas Class 3\Superstore_USA.xlsx")
df_return=pd.read_excel(r"C:\Users\Dell\Documents\Ineuron FSDS Resourse\(20) Pandas Class 3\Superstore_USA.xlsx",sheet_name="Returns")
df_users=pd.read_excel(r"C:\Users\Dell\Documents\Ineuron FSDS Resourse\(20) Pandas Class 3\Superstore_USA.xlsx",sheet_name="Users")

# %%
df_order.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df_order.shape
# Out:
# (9426, 24)

# %%
#3 . Find out how return that we have recived and with a product id.

df_returned=pd.read_excel(r"C:\Users\Dell\Documents\Ineuron FSDS Resourse\(20) Pandas Class 3\Superstore_USA.xlsx",sheet_name="Returns")

# %%
df_returned
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
#4 . try  to join order and return data in pandas.

df_return.merge(df_order)
# Out:
#     Order ID    Status  Row ID Order Priority  Discount  Unit Price  \
# 0        612  Returned      95         Medium      0.10        5.28
# 1        612  Returned      96         Medium      0.01       65.99
# 2       4610  Returned     653            Low      0.09        8.33
# 3       4610  Returned     654            Low      0.08       15.67
# 4       7079  Returned     979         Medium      0.01      280.98
# ..       ...       ...     ...            ...       ...         ...
# 93     57638  Returned    8079            Low      0.09      217.85
# 94     57638  Returned    8080            Low      0.07       11.48
# 95     57638  Returned    8081            Low      0.08        2.08
# 96     59009  Returned    8251       Critical      0.02       30.98
# 97     59937  Returned    8389           High      0.02       30.98
#
#     Shipping Cost  Customer ID     Customer Name       Ship Mode  ...  \
# 0            6.26         3011      Tammy Raynor     Regular Air  ...
# ...

# %%
#5 . Try to find out how many unique customer that we have.
len(df_order.groupby("Customer Name")["Customer Name"].unique())

# total 2703 unique customers we have
# Out:
# 2703

# %%
df_order["Customer Name"].drop_duplicates()
# Out:
# 0       Janice Fletcher
# 1         Bonnie Potter
# 7        Ronnie Proctor
# 9          Dwight Hwang
# 13            Leon Gill
#              ...
# 9406      Marc McDaniel
# 9409        Marvin Reid
# 9413      Florence Gold
# 9420     Frederick Cole
# 9424      Tammy Buckley
# Name: Customer Name, Length: 2703, dtype: object

# %%
len(df_order["Customer Name"].drop_duplicates())
# total 2703 unique customers we have
# Out:
# 2703

# %%
#6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

df_order["Region"].drop_duplicates()

# in total 4 region we are selling the product.
# Out:
# 0      Central
# 1         West
# 13        East
# 113      South
# Name: Region, dtype: object

# %%
df_users.merge(df_order["Region"].drop_duplicates())

# these are the managers of perticular regions.
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#7 . find out how many different  shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 

df_order["Ship Mode"].value_counts(normalize=True)

#Value_counts: counts the total of unique values.
#value_counts(normalize=True): this counts the percentage of all unique value in dataframe.
# Out:
# Regular Air       0.746446
# Delivery Truck    0.136113
# Express Air       0.117441
# Name: Ship Mode, dtype: float64

# %%
#8 . Create a new coulmn and try to find our a diffrence between order date and shipment date.

# %%
df_order["Difference_orderdate_shipdate"]=df_order["Ship Date"]-df_order["Order Date"]

# %%
df_order.head()
#here we are getting difference in days.
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
#9.Based on question number 8 find out for which order id we have shipment duration more than 10 days.

df_order.dtypes

# Here datatype of "Difference_orderdate_shipdate ----> timedelta64[ns]"
#so we can not perform only integer operation on this.
# Out:
# Row ID                                     int64
# Order Priority                            object
# Discount                                 float64
# Unit Price                               float64
# Shipping Cost                            float64
# Customer ID                                int64
# Customer Name                             object
# Ship Mode                                 object
# Customer Segment                          object
# Product Category                          object
# Product Sub-Category                      object
# Product Container                         object
# Product Name                              object
# Product Base Margin                      float64
# Region                                    object
# State or Province                         object
# City                                      object
# Postal Code                                int64
# Order Date                        datetime64[ns]
# ...

# %%
df_order.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
#converting timedelta64[ns] into str format
df_order["Difference_orderdate_shipdate"]=df_order["Difference_orderdate_shipdate"].astype(str)

# %%
# Now remove the string "days" from  this
df_order["Difference_orderdate_shipdate"]=df_order["Difference_orderdate_shipdate"].str.replace("days","")

# %%
# Now convet the data from this str fromat to int format.
df_order["Difference_orderdate_shipdate"]=df_order["Difference_orderdate_shipdate"].astype(int)

# %%
df_order.dtypes
# Out:
# Row ID                                    int64
# Order Priority                           object
# Discount                                float64
# Unit Price                              float64
# Shipping Cost                           float64
# Customer ID                               int64
# Customer Name                            object
# Ship Mode                                object
# Customer Segment                         object
# Product Category                         object
# Product Sub-Category                     object
# Product Container                        object
# Product Name                             object
# Product Base Margin                     float64
# Region                                   object
# State or Province                        object
# City                                     object
# Postal Code                               int64
# Order Date                       datetime64[ns]
# Ship Date                        datetime64[ns]
# ...

# %%
#Now "Difference_orderdate_shipdate " converted in int format, now we can perform operation on it.

# %%
df_order[df_order["Difference_orderdate_shipdate"]>10][["Order ID","Difference_orderdate_shipdate"]]
# Out:
#       Order ID  Difference_orderdate_shipdate
# 643      87215                             84
# 1548     86318                             11
# 1549     86318                             15
# 1678     87957                             17
# 1679     87957                             11
# 1680     87957                             28
# 1697     19556                             17
# 1698     19556                             11
# 1699     19556                             28
# 2515     86177                             92
# 5548     88223                             14
# 5673     88352                             17
# 5859     87572                             22
# 5881     91294                             24
# 8607     86434                             18
# 8609     86436                             17
# 8610     86436                             19
# 8973     87300                             19
# 8982     19841                             27
# ...

# %%
#10.Try to find out a list of a returned order which shipment duration was more then 15 days and find out that region manager as well

# %%
#merging the return dataframe with order dataframe, bcz both are in different sheets
merge_status_df=df_order.merge(df_return)

# %%
merge_status_df
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
merge_status_df.dtypes
# Out:
# Row ID                                    int64
# Order Priority                           object
# Discount                                float64
# Unit Price                              float64
# Shipping Cost                           float64
# Customer ID                               int64
# Customer Name                            object
# Ship Mode                                object
# Customer Segment                         object
# Product Category                         object
# Product Sub-Category                     object
# Product Container                        object
# Product Name                             object
# Product Base Margin                     float64
# Region                                   object
# State or Province                        object
# City                                     object
# Postal Code                               int64
# Order Date                       datetime64[ns]
# Ship Date                        datetime64[ns]
# ...

# %%
merge_status_df[(merge_status_df["Status"]=="Returned") & (merge_status_df["Difference_orderdate_shipdate"]>5)].merge(df_users)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    7234            Low      0.09       25.98           4.08          949
# 1    4627            Low      0.06        2.88           0.50         3004
# 2    5883            Low      0.00        9.98          12.52         1228
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0        Ernest Oh  Regular Air         Consumer  Office Supplies  ...
# 1  Maurice Everett  Regular Air        Corporate  Office Supplies  ...
# 2   Hazel Jennings  Regular Air   Small Business        Furniture  ...
#
#   Postal Code Order Date  Ship Date   Profit Quantity ordered new   Sales  \
# 0       90049 2013-03-04 2013-03-13  129.810                   34  823.98
# 1       90049 2011-02-15 2011-02-22   32.700                   31   86.10
# 2       19140 2013-01-27 2013-02-03 -213.088                   24  269.95
#
#   Order ID  Difference_orderdate_shipdate    Status  Manager
# ...

# %%
#11 . Gorup by region and find out which region is more profitable.

df_order.groupby('Region')["Profit"].agg([sum,max]) 

#this will gives total sum of profit of individual region
# And will also give maximum profit in each region
---------------------------------------------------------------------------------------------------------
# "Most profitable region is Central region, bcz its sum of profit is higher"
# Out:
#                    sum         max
# Region
# Central  519825.567067  12504.9045
# East     377566.186045   9228.2256
# South    104201.192420  16332.4140
# West     310849.453897   8917.7187

# %%
#12.Try to find out overalll in which country we are giving more discount.

pd.DataFrame(df_order.groupby("Region")["Discount"].sum())

#or we can also write as given in next cell
#------------------------------------------------------------------------------------------------------------------------------

# as per data frame in Central region we are giving more discount.
# Out:
#          Discount
# Region
# Central    143.06
# East       114.45
# South       96.53
# West       113.75

# %%
df_order.groupby("Region")["Discount"].sum()
# Out:
# Region
# Central    143.06
# East       114.45
# South       96.53
# West       113.75
# Name: Discount, dtype: float64

# %%
#13 . Give me a list of unique postal code.

len(df_order["Postal Code"].unique())
#---------------------------------------------------------------------------------------------------------

#There are total 1697 postal codes we have
# Out:
# 1697

# %%
#13 . Give me a list of unique postal code.

#method2:
len(df_order["Postal Code"].drop_duplicates())

#---------------------------------------------------------------------------------------------------------

#There are total 1697 postal codes we have
# Out:
# 1697

# %%
#14 . which customer segement is more profitalble find it out . 


pd.DataFrame(df_order.groupby("Customer Segment")["Profit"].sum())

#---------------------------------------------------------------------------------------------------------

#from this dataframe it is seen that "Corporate" is the most profitable
# Out:
#                          Profit
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482

# %%
#15 . try to find out the 10th most loss making product catagory . 
df_order.groupby("Product Category")["Profit"].sum()

#---------------------------------------------------------------------------------------------------

# There are only 3 product categoty only in the dataframe
# hence que is not valid
# Out:
# Product Category
# Furniture          177354.298188
# Office Supplies    451990.216492
# Technology         683097.884748
# Name: Profit, dtype: float64

# %%
#16 . Try to find out 10 top  product with highest margins.

highest_margin=df_order.groupby("Product Sub-Category")["Product Base Margin"].sum().reset_index().sort_values(by="Product Base Margin",ascending=False)

# %%
highest_margin
# Out:
#               Product Sub-Category  Product Base Margin
# 16    Telephones and Communication               576.76
# 10                           Paper               517.09
# 4             Computer Peripherals               500.91
# 8               Office Furnishings               463.23
# 14          Storage & Organization               390.26
# 1   Binders and Binder Accessories               384.57
# 11             Pens & Art Supplies               384.57
# 0                       Appliances               273.00
# 15                          Tables               271.19
# 3               Chairs & Chairmats               260.59
# 9                  Office Machines               167.64
# 2                        Bookcases               132.67
# 7                           Labels               123.97
# 12                    Rubber Bands               102.09
# 6                        Envelopes               101.66
# 13   Scissors, Rulers and Trimmers                99.56
# ...

# %%
highest_margin.loc[[16,10,4,8,14,1,11,10,15,3]]

#---------------------------------------------------------------------------------------------------------------------------------------
#these are the top 10 products who have received heighest margin.
# Out:
#               Product Sub-Category  Product Base Margin
# 16    Telephones and Communication               576.76
# 10                           Paper               517.09
# 4             Computer Peripherals               500.91
# 8               Office Furnishings               463.23
# 14          Storage & Organization               390.26
# 1   Binders and Binder Accessories               384.57
# 11             Pens & Art Supplies               384.57
# 10                           Paper               517.09
# 15                          Tables               271.19
# 3               Chairs & Chairmats               260.59

# %%
df_order.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID',
#        'Difference_orderdate_shipdate'],
#       dtype='object')
